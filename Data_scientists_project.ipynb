# %%
import pandas as pd 
import numpy as np

import matplotlib 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df = pd.read_csv("/Users/boystekelbos/Downloads/ds_salaries.csv")

# %%
df.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# ...

# %%
# Sees if any data is missing

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    
   
    
    print('{} - {}%'.format(col ,pct_missing))
# Out:
# Unnamed: 0 - 0.0%
# work_year - 0.0%
# experience_level - 0.0%
# employment_type - 0.0%
# job_title - 0.0%
# salary - 0.0%
# salary_currency - 0.0%
# salary_in_usd - 0.0%
# employee_residence - 0.0%
# remote_ratio - 0.0%
# company_location - 0.0%
# company_size - 0.0%

# %%
df.dtypes
# Out:
# Unnamed: 0             int64
# work_year              int64
# experience_level      object
# employment_type       object
# job_title             object
# salary                 int64
# salary_currency       object
# salary_in_usd          int64
# employee_residence    object
# remote_ratio           int64
# company_location      object
# company_size          object
# dtype: object

# %%
df.sort_values(by=['salary_in_usd'], inplace=False, ascending=False)


# print(np.mean(df["salary_in_usd"]))
# Out:
#      Unnamed: 0  work_year experience_level employment_type  \
# 252         252       2021               EX              FT
# 97           97       2021               MI              FT
# 33           33       2020               MI              FT
# 157         157       2021               MI              FT
# 225         225       2021               EX              CT
# ..          ...        ...              ...             ...
# 179         179       2021               MI              FT
# 77           77       2021               MI              PT
# 238         238       2021               EN              FT
# 185         185       2021               MI              FT
# 176         176       2021               MI              FT
#
#                               job_title  salary salary_currency  \
# 252             Principal Data Engineer  600000             USD
# 97               Financial Data Analyst  450000             USD
# ...

# %%
# Changes the settings so all rows are displayed
pd.set_option("display.max_rows",None)

# %%
# Checks for duplicates and drops them so it only displays unique values
df['job_title'].drop_duplicates().sort_values(ascending=False)

# df['job_title'].sort_values(ascending =False)
# Out:
# 283                        Staff Data Scientist
# 26                           Research Scientist
# 3                          Product Data Analyst
# 55                     Principal Data Scientist
# 121                     Principal Data Engineer
# 249                      Principal Data Analyst
# 455                                NLP Engineer
# 90                       Marketing Data Analyst
# 1                    Machine Learning Scientist
# 29                     Machine Learning Manager
# 42     Machine Learning Infrastructure Engineer
# 4                     Machine Learning Engineer
# 130                  Machine Learning Developer
# 45                                  ML Engineer
# 457              Lead Machine Learning Engineer
# 6                           Lead Data Scientist
# 9                            Lead Data Engineer
# 13                            Lead Data Analyst
# 384                    Head of Machine Learning
# 161                        Head of Data Science
# ...

# %%
df.head(10)
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
# 5           5       2020               EN              FT
# 6           6       2020               SE              FT
# 7           7       2020               MI              FT
# 8           8       2020               MI              FT
# 9           9       2020               SE              FT
#
#                     job_title    salary salary_currency  salary_in_usd  \
# 0              Data Scientist     70000             EUR          79833
# 1  Machine Learning Scientist    260000             USD         260000
# 2           Big Data Engineer     85000             GBP         109024
# ...

# %%
# Assumptions:

#employee residence high correlation
#experience level high correlation


#Scatterplot
plt.scatter(x=df['remote_ratio'],y=df['salary_in_usd'])
plt.title("Salary vs remote work")
plt.xlabel('remote_ratio')
plt.ylabel(salary)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [28], in <cell line: 10>()
#       8 plt.scatter(x=df['remote_ratio'],y=df['salary_in_usd'])
#       9 plt.title("Salary vs remote work")
# ---> 10 plt.xlabel('remote_ratio')
#      11 plt.ylabel(salary)
#      12 plt.show()
#
# TypeError: 'str' object is not callable

# %%
df.corr()
# Out:
#                Unnamed: 0  work_year    salary  salary_in_usd  remote_ratio
# Unnamed: 0       1.000000   0.886550 -0.096250       0.167025      0.095000
# work_year        0.886550   1.000000 -0.087577       0.170493      0.076314
# salary          -0.096250  -0.087577  1.000000      -0.083906     -0.014608
# salary_in_usd    0.167025   0.170493 -0.083906       1.000000      0.132122
# remote_ratio     0.095000   0.076314 -0.014608       0.132122      1.000000

# %%
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix,annot=True)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
correlation_matrix = df.corr()

corr_pairs = correlation_matrix.unstack()

corr_pairs
# Out:
# Unnamed: 0     Unnamed: 0       1.000000
#                work_year        0.886550
#                salary          -0.096250
#                salary_in_usd    0.167025
#                remote_ratio     0.095000
# work_year      Unnamed: 0       0.886550
#                work_year        1.000000
#                salary          -0.087577
#                salary_in_usd    0.170493
#                remote_ratio     0.076314
# salary         Unnamed: 0      -0.096250
#                work_year       -0.087577
#                salary           1.000000
#                salary_in_usd   -0.083906
#                remote_ratio    -0.014608
# salary_in_usd  Unnamed: 0       0.167025
#                work_year        0.170493
#                salary          -0.083906
#                salary_in_usd    1.000000
#                remote_ratio     0.132122
# remote_ratio   Unnamed: 0       0.095000
#                work_year        0.076314
#                salary          -0.014608
# ...

# %%
sorted_correlations = corr_pairs.sort_values()

sorted_correlations
# Out:
# salary         Unnamed: 0      -0.096250
# Unnamed: 0     salary          -0.096250
# work_year      salary          -0.087577
# salary         work_year       -0.087577
# salary_in_usd  salary          -0.083906
# salary         salary_in_usd   -0.083906
#                remote_ratio    -0.014608
# remote_ratio   salary          -0.014608
#                work_year        0.076314
# work_year      remote_ratio     0.076314
# remote_ratio   Unnamed: 0       0.095000
# Unnamed: 0     remote_ratio     0.095000
# remote_ratio   salary_in_usd    0.132122
# salary_in_usd  remote_ratio     0.132122
#                Unnamed: 0       0.167025
# Unnamed: 0     salary_in_usd    0.167025
# work_year      salary_in_usd    0.170493
# salary_in_usd  work_year        0.170493
# work_year      Unnamed: 0       0.886550
# Unnamed: 0     work_year        0.886550
#                Unnamed: 0       1.000000
# salary         salary           1.000000
# work_year      work_year        1.000000
# ...

# %%
# Shows high correlations only
sorted_correlations[(sorted_correlations) > 0.5]
# Out:
# work_year      Unnamed: 0       0.88655
# Unnamed: 0     work_year        0.88655
#                Unnamed: 0       1.00000
# salary         salary           1.00000
# work_year      work_year        1.00000
# salary_in_usd  salary_in_usd    1.00000
# remote_ratio   remote_ratio     1.00000
# dtype: float64

# %%
# Remote ratio and salary have a high correlation probably due to the fact that more experienced employees are able to work from home but increased experience leads to increased salary as well
